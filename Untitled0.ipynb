# %% [markdown]
# <a href="https://colab.research.google.com/github/sebastian810/programacion/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib. pyplot as plt 
import cv2

x  = [1,2,3,4,5,6,7,8,9]
y1 = [1,3,5,3,1,3,5,3,1]
y2 = [2,4,6,4,2,4,6,4,2]
plt.plot (x, y1, label="line L")
plt.plot (x, y2, label="line H")

plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("grafico de lineas")
plt.legend()
plt.show()
